# %%
# Replace NaN with 0
# df_drop = df.fillna(0)
# df_drop.head()

# %%
import pandas as pd
import csv
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
df_1950 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1950_c20170120.csv')
df_1951 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1951_c20160223.csv')
df_1952 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1952_c20170619.csv')
df_1953 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1953_c20160223.csv')
df_1954 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1954_c20160223.csv')
df_1955 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1955_c20160223.csv')
df_1956 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1956_c20170717.csv')
df_1957 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1957_c20160223.csv')
df_1958 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1958_c20160223.csv')
df_1959 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1959_c20160223.csv')
df_1960 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1960_c20160223.csv')
df_1961 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1961_c20160223.csv')
df_1962 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1962_c20160223.csv')
df_1963 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1963_c20160223.csv')
df_1964 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1964_c20160223.csv')
df_1965 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1965_c20190920.csv')
df_1966 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1966_c20160223.csv')
df_1967 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1967_c20160223.csv')
df_1968 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1968_c20160223.csv')
df_1969 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1969_c20170717.csv')
df_1970 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1970_c20160223.csv')
df_1971 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1971_c20160223.csv')
df_1972 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1972_c20181029.csv')
df_1973 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1973_c20160223.csv')
df_1974 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1974_c20160223.csv')
df_1975 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1975_c20160223.csv')
df_1976 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1976_c20160223.csv')
df_1977 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1977_c20160223.csv')
df_1978 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1978_c20160223.csv')
df_1979 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1979_c20160223.csv')
df_1980 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1980_c20170717.csv')
df_1981 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1981_c20170717.csv')
df_1982 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1982_c20160223.csv')
df_1983 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1983_c20160223.csv')
df_1984 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1984_c20170717.csv')
df_1985 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1985_c20160223.csv')
df_1986 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1986_c20160223.csv')
df_1987 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1987_c20160223.csv')
df_1988 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1988_c20170717.csv')
df_1989 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1989_c20170717.csv')
df_1990 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1990_c20170717.csv')
df_1991 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1991_c20170717.csv')
df_1992 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1992_c20170717.csv')
df_1993 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1993_c20190920.csv')
df_1994 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1994_c20190920.csv')
df_1995 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1995_c20190920.csv')
df_1996 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1996_c20170717.csv')
df_1997 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1997_c20190920.csv')
df_1998 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1998_c20170717.csv')
# df_1999 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d1950_c20170120.csv')
df_2000 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2000_c20200707.csv')
df_2001 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2001_c20200518.csv')
df_2002 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2002_c20200518.csv')
df_2003 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2003_c20200518.csv')
df_2004 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2004_c20200518.csv')
df_2005 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2005_c20200518.csv')
df_2006 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2006_c20200518.csv')
df_2007 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2007_c20170717.csv')
df_2008 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2008_c20180718.csv')
df_2009 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2009_c20180718.csv')
df_2010 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2010_c20200922.csv')
df_2011 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2011_c20180718.csv')
df_2012 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2012_c20200317.csv')
df_2013 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2013_c20170519.csv')
df_2014 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2014_c20191116.csv')
df_2015 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2015_c20191116.csv')
df_2016 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2016_c20190817.csv')
df_2017 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2017_c20200616.csv')
df_2018 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2018_c20200819.csv')
df_2019 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2019_c20201017.csv')
df_2020 = pd.read_csv (r'/Users/ronaldrivas/Desktop/Severe Storm Bulk Data/Storm Event/Details/StormEvents_details-ftp_v1.0_d2020_c20201017.csv')
# Out:
# /Users/ronaldrivas/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (26,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/ronaldrivas/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/ronaldrivas/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (29,34,35,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# # Find the columns where each value is null
# empty_cols = [col for col in df.columns if df[col].isnull().all()]

# # Drop these columns from the dataframe
# df.drop(empty_cols, axis=1,inplace=True)

# %%
# For Year 2020
# Find the columns where each value is null
empty_cols_2020 = [col for col in df_2020.columns if df_2020[col].isnull().all()]

# Drop these columns from the dataframe
df_2020.drop(empty_cols_2020, axis=1, inplace=True)

df_2020.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           202006         24        1620         202006       24      1620
# 1           202005         25        1700         202005       25      2000
# 2           202005         22        1931         202005       22      1931
# 3           202005         22        1932         202005       22      1932
# 4           202004         10           0         202004       10      1500
#
#    EPISODE_ID  EVENT_ID          STATE  STATE_FIPS  ...  END_RANGE  \
# 0      149684    902190        GEORGIA          13  ...        1.0
# 1      147310    885808  WEST VIRGINIA          54  ...        2.0
# 2      147059    883975        ALABAMA           1  ...        0.0
# 3      147059    883976        ALABAMA           1  ...        0.0
# 4      145924    881761  WEST VIRGINIA          54  ...        NaN
#
#   END_AZIMUTH END_LOCATION BEGIN_LAT  BEGIN_LON  END_LAT  END_LON  \
# ...

# %%
# Choose valuable columns (testing)

df_1950 = df_1950[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]

df_1950.head()
# Out:
#           STATE EVENT_TYPE     BEGIN_DATE_TIME  INJURIES_DIRECT  \
# 0      OKLAHOMA    Tornado  28-APR-50 14:45:00                0
# 1         TEXAS    Tornado  29-APR-50 15:30:00                0
# 2  PENNSYLVANIA    Tornado  05-JUL-50 18:00:00                2
# 3  PENNSYLVANIA    Tornado  05-JUL-50 18:30:00                0
# 4  PENNSYLVANIA    Tornado  24-JUL-50 14:40:00                0
#
#    INJURIES_INDIRECT  DEATHS_DIRECT  DEATHS_INDIRECT DAMAGE_PROPERTY  \
# 0                  0              0                0            250K
# 1                  0              0                0             25K
# 2                  0              0                0             25K
# 3                  0              0                0            2.5K
# 4                  0              0                0            2.5K
#
#    DAMAGE_CROPS  MAGNITUDE  CATEGORY TOR_F_SCALE
# 0             0          0       NaN          F3
# 1             0          0       NaN          F1
# ...

# %%
df_1950 = df_1950[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1951 = df_1951[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1952 = df_1952[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1953 = df_1953[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1954 = df_1954[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1955 = df_1955[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1956 = df_1956[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1957 = df_1957[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1958 = df_1958[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1959 = df_1959[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1960 = df_1960[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1961 = df_1961[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1962 = df_1962[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1963 = df_1963[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1964 = df_1964[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1965 = df_1965[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1966 = df_1966[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1967 = df_1967[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1968 = df_1968[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1969 = df_1969[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1970 = df_1970[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1971 = df_1971[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1972 = df_1972[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1973 = df_1973[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1974 = df_1974[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1975 = df_1975[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1976 = df_1976[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1977 = df_1977[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1978 = df_1978[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1979 = df_1979[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1980 = df_1980[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1981 = df_1981[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1982 = df_1982[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1983 = df_1983[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1984 = df_1984[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1985 = df_1985[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1986 = df_1986[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1987 = df_1987[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1988 = df_1988[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1989 = df_1989[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1990 = df_1990[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1991 = df_1991[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1992 = df_1992[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1993 = df_1993[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1994 = df_1994[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1995 = df_1995[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1996 = df_1996[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1997 = df_1997[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_1998 = df_1998[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
# df_1999 = df_1999[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2000 = df_2000[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2001 = df_2001[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2002 = df_2002[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2003 = df_2003[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2004 = df_2004[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2005 = df_2005[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2006 = df_2006[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2007 = df_2007[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2008 = df_2008[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2009 = df_2009[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2010 = df_2010[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2011 = df_2011[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2012 = df_2012[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2013 = df_2013[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2014 = df_2014[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2015 = df_2015[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2016 = df_2016[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2017 = df_2017[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2018 = df_2018[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2019 = df_2019[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]
df_2020 = df_2020[["STATE","EVENT_TYPE","BEGIN_DATE_TIME","INJURIES_DIRECT","INJURIES_INDIRECT","DEATHS_DIRECT","DEATHS_INDIRECT","DAMAGE_PROPERTY","DAMAGE_CROPS","MAGNITUDE","CATEGORY","TOR_F_SCALE"]]

# %%
df_2020.head()
# Out:
#            STATE         EVENT_TYPE     BEGIN_DATE_TIME  INJURIES_DIRECT  \
# 0        GEORGIA  Thunderstorm Wind  24-JUN-20 16:20:00                0
# 1  WEST VIRGINIA        Flash Flood  25-MAY-20 17:00:00                0
# 2        ALABAMA               Hail  22-MAY-20 19:31:00                0
# 3        ALABAMA               Hail  22-MAY-20 19:32:00                0
# 4  WEST VIRGINIA        Strong Wind  10-APR-20 00:00:00                0
#
#    INJURIES_INDIRECT  DEATHS_DIRECT  DEATHS_INDIRECT DAMAGE_PROPERTY  \
# 0                  0              0                0           0.00K
# 1                  0              0                0           3.00K
# 2                  0              0                0           0.00K
# 3                  0              0                0           0.00K
# 4                  0              0                0           5.00K
#
#   DAMAGE_CROPS  MAGNITUDE  CATEGORY TOR_F_SCALE
# 0        0.00K      50.00       NaN         NaN
# ...

# %%
# Joining of Pandas Dataframes
df_merge = pd.concat([df_1950,df_1951,df_1952,df_1953,df_1954,df_1955,df_1956,df_1957,df_1958,df_1959,
                      df_1960,df_1961,df_1962,df_1963,df_1964,df_1965,df_1966,df_1967,df_1968,df_1969,
                     df_1970,df_1971,df_1972,df_1973,df_1974,df_1975,df_1976,df_1977,df_1978,df_1979,
                     df_1980,df_1981,df_1982,df_1983,df_1984,df_1985,df_1986,df_1987,df_1988,df_1989,
                     df_1990,df_1991,df_1992,df_1993,df_1994,df_1995,df_1996,df_1997,df_1998,
                     df_2000,df_2001,df_2002,df_2003,df_2004,df_2005,df_2006,df_2007,df_2008,df_2009,
                     df_2010,df_2011,df_2012,df_2013,df_2014,df_2015,df_2016,df_2017,df_2018,df_2019,df_2020])
                      
df_merge.head()
# Out:
#           STATE EVENT_TYPE     BEGIN_DATE_TIME  INJURIES_DIRECT  \
# 0      OKLAHOMA    Tornado  28-APR-50 14:45:00                0
# 1         TEXAS    Tornado  29-APR-50 15:30:00                0
# 2  PENNSYLVANIA    Tornado  05-JUL-50 18:00:00                2
# 3  PENNSYLVANIA    Tornado  05-JUL-50 18:30:00                0
# 4  PENNSYLVANIA    Tornado  24-JUL-50 14:40:00                0
#
#    INJURIES_INDIRECT  DEATHS_DIRECT  DEATHS_INDIRECT DAMAGE_PROPERTY  \
# 0                  0              0                0            250K
# 1                  0              0                0             25K
# 2                  0              0                0             25K
# 3                  0              0                0            2.5K
# 4                  0              0                0            2.5K
#
#   DAMAGE_CROPS  MAGNITUDE  CATEGORY TOR_F_SCALE
# 0            0        0.0       NaN          F3
# 1            0        0.0       NaN          F1
# ...

# %%
# Reseting the index 
df_merge = df_merge.reset_index(drop=True)
df_merge
# Out:
#                 STATE  EVENT_TYPE     BEGIN_DATE_TIME  INJURIES_DIRECT  \
# 0            OKLAHOMA     Tornado  28-APR-50 14:45:00                0
# 1               TEXAS     Tornado  29-APR-50 15:30:00                0
# 2        PENNSYLVANIA     Tornado  05-JUL-50 18:00:00                2
# 3        PENNSYLVANIA     Tornado  05-JUL-50 18:30:00                0
# 4        PENNSYLVANIA     Tornado  24-JUL-50 14:40:00                0
# ...               ...         ...                 ...              ...
# 1595872          IOWA  Heavy Rain  18-JUN-20 06:00:00                0
# 1595873          IOWA  Heavy Rain  18-JUN-20 06:00:00                0
# 1595874          IOWA       Flood  22-JUN-20 23:20:00                0
# 1595875          IOWA       Flood  23-JUN-20 00:38:00                0
# 1595876          IOWA       Flood  23-JUN-20 01:24:00                0
#
#          INJURIES_INDIRECT  DEATHS_DIRECT  DEATHS_INDIRECT DAMAGE_PROPERTY  \
# ...

# %%
Event_Type_Data_GB = df_merge.groupby(["EVENT_TYPE"])
test = Event_Type_Data_GB["STATE"].count()
test.keys()
# Out:
# Index(['Astronomical Low Tide', 'Avalanche', 'Blizzard', 'Coastal Flood',
#        'Cold/Wind Chill', 'Debris Flow', 'Dense Fog', 'Dense Smoke', 'Drought',
#        'Dust Devil', 'Dust Storm', 'Excessive Heat', 'Extreme Cold/Wind Chill',
#        'Flash Flood', 'Flood', 'Freezing Fog', 'Frost/Freeze', 'Funnel Cloud',
#        'HAIL FLOODING', 'HAIL/ICY ROADS', 'Hail', 'Heat', 'Heavy Rain',
#        'Heavy Snow', 'Heavy Wind', 'High Snow', 'High Surf', 'High Wind',
#        'Hurricane', 'Hurricane (Typhoon)', 'Ice Storm', 'Lake-Effect Snow',
#        'Lakeshore Flood', 'Landslide', 'Lightning', 'Marine Dense Fog',
#        'Marine Hail', 'Marine High Wind', 'Marine Hurricane/Typhoon',
#        'Marine Lightning', 'Marine Strong Wind', 'Marine Thunderstorm Wind',
#        'Marine Tropical Depression', 'Marine Tropical Storm',
#        'Northern Lights', 'OTHER', 'Rip Current', 'Seiche', 'Sleet',
#        'Sneakerwave', 'Storm Surge/Tide', 'Strong Wind',
# ...

# %%
# Testing Event_Type join, similar event to tornadoes
df_merge.loc[df_merge.EVENT_TYPE == 'TORNADO/WATERSPOUT'] = "Tornadoes"
df_merge.loc[df_merge.EVENT_TYPE == 'Waterspout'] = "Tornadoes"
df_merge.loc[df_merge.EVENT_TYPE == 'TORNADOES, TSTM WIND, HAIL'] = "Tornadoes"
df_merge.loc[df_merge.EVENT_TYPE == 'Dust Devil'] = "Tornadoes"
df_merge.loc[df_merge.EVENT_TYPE == 'Tornado'] = "Tornadoes"
df_merge.loc[df_merge.EVENT_TYPE == 'Funnel Cloud'] = "Tornadoes"

# Testing Event_Type join, similar event to Floods
df_merge.loc[df_merge.EVENT_TYPE == 'Lakeshore Flood'] = "Floods"
df_merge.loc[df_merge.EVENT_TYPE == 'Coastal Flood'] = "Floods"
df_merge.loc[df_merge.EVENT_TYPE == 'Debris Flow'] = "Floods"
df_merge.loc[df_merge.EVENT_TYPE == 'Flood'] = "Floods"
df_merge.loc[df_merge.EVENT_TYPE == 'Flash Flood'] = "Floods"
df_merge.loc[df_merge.EVENT_TYPE == 'THUNDERSTORM WINDS/FLASH FLOOD'] = "Floods"
df_merge.loc[df_merge.EVENT_TYPE == 'THUNDERSTORM WINDS/FLOODING'] = "Floods"
df_merge.loc[df_merge.EVENT_TYPE == 'Heavy Rain'] = "Floods"

# Testing Event_Type join, similar event to Hurricanes
df_merge.loc[df_merge.EVENT_TYPE == 'Tropical Depression'] = "Hurricanes"
df_merge.loc[df_merge.EVENT_TYPE == 'Tropical Storm'] = "Hurricanes"
df_merge.loc[df_merge.EVENT_TYPE == 'Hurricane'] = "Hurricanes"
df_merge.loc[df_merge.EVENT_TYPE == 'Hurricane (Typhoon)'] = "Hurricanes"
df_merge.loc[df_merge.EVENT_TYPE == 'Marine Hurricane/Typhoon'] = "Hurricanes"
df_merge.loc[df_merge.EVENT_TYPE == 'Marine Tropical Storm'] = "Hurricanes"
df_merge.loc[df_merge.EVENT_TYPE == 'Marine Tropical Depression'] = "Hurricanes"

# Testing Event_Type join, similar event to Winds
df_merge.loc[df_merge.EVENT_TYPE == 'Marine High Wind'] = "Winds"
df_merge.loc[df_merge.EVENT_TYPE == 'Marine Strong Wind'] = "Winds"
df_merge.loc[df_merge.EVENT_TYPE == 'Strong Wind'] = "Winds"
df_merge.loc[df_merge.EVENT_TYPE == 'High Wind'] = "Winds"
df_merge.loc[df_merge.EVENT_TYPE == 'Heavy Wind'] = "Winds"
df_merge.loc[df_merge.EVENT_TYPE == 'Wind'] = "Winds"

# Testing Event_Type join, similar event to Snow
df_merge.loc[df_merge.EVENT_TYPE == 'Sleet'] = "Snow"
df_merge.loc[df_merge.EVENT_TYPE == 'Frost/Freeze'] = "Snow"
df_merge.loc[df_merge.EVENT_TYPE == 'Lake-Effect Snow'] = "Snow"
df_merge.loc[df_merge.EVENT_TYPE == 'Freezing Fog'] = "Snow"
df_merge.loc[df_merge.EVENT_TYPE == 'Extreme Cold/Wind Chill'] = "Snow"
df_merge.loc[df_merge.EVENT_TYPE == 'Avalanche'] = "Snow"
df_merge.loc[df_merge.EVENT_TYPE == 'Blizzard'] = "Snow"
df_merge.loc[df_merge.EVENT_TYPE == 'Cold/Wind Chill'] = "Snow"
df_merge.loc[df_merge.EVENT_TYPE == 'Heavy Snow'] = "Snow"
df_merge.loc[df_merge.EVENT_TYPE == 'Ice Storm'] = "Snow"
df_merge.loc[df_merge.EVENT_TYPE == 'Winter Storm'] = "Snow"
df_merge.loc[df_merge.EVENT_TYPE == 'Winter Weather'] = "Snow"
df_merge.loc[df_merge.EVENT_TYPE == 'High Snow'] = "Snow"

# Testing Event_Type join, similar event to Body of Waters
df_merge.loc[df_merge.EVENT_TYPE == 'Storm Surge/Tide'] = "Body of Waters"
df_merge.loc[df_merge.EVENT_TYPE == 'Sneakerwave'] = "Body of Waters"
df_merge.loc[df_merge.EVENT_TYPE == 'High Surf'] = "Body of Waters"
df_merge.loc[df_merge.EVENT_TYPE == 'Rip Current'] = "Body of Waters"
df_merge.loc[df_merge.EVENT_TYPE == 'Astronomical Low Tide'] = "Body of Waters"
df_merge.loc[df_merge.EVENT_TYPE == 'Sneakerwave'] = "Body of Waters"
df_merge.loc[df_merge.EVENT_TYPE == 'Seiche'] = "Body of Waters"

# Testing Event_Type join, similar event to Thunderstorm
df_merge.loc[df_merge.EVENT_TYPE == 'Lightning'] = "Thunderstorms"
df_merge.loc[df_merge.EVENT_TYPE == 'Marine Lightning'] = "Thunderstorms"
df_merge.loc[df_merge.EVENT_TYPE == 'Marine Thunderstorm Wind'] = "Thunderstorms"
df_merge.loc[df_merge.EVENT_TYPE == 'THUNDERSTORM WIND/ TREE'] = "Thunderstorms"
df_merge.loc[df_merge.EVENT_TYPE == 'THUNDERSTORM WIND/ TREES'] = "Thunderstorms"
df_merge.loc[df_merge.EVENT_TYPE == 'THUNDERSTORM WINDS FUNNEL CLOU'] = "Thunderstorms"
df_merge.loc[df_merge.EVENT_TYPE == 'THUNDERSTORM WINDS HEAVY RAIN'] = "Thunderstorms"
df_merge.loc[df_merge.EVENT_TYPE == 'THUNDERSTORM WINDS LIGHTNING'] = "Thunderstorms"
df_merge.loc[df_merge.EVENT_TYPE == 'THUNDERSTORM WINDS/ FLOOD'] = "Thunderstorms"
df_merge.loc[df_merge.EVENT_TYPE == 'THUNDERSTORM WINDS/HEAVY RAIN'] = "Thunderstorms"
df_merge.loc[df_merge.EVENT_TYPE == 'Thunderstorm Wind'] = "Thunderstorms"


# Testing Event_Type join, similar event to Heat
df_merge.loc[df_merge.EVENT_TYPE == 'Excessive Heat'] = "Heat"

# Testing Event_Type join, similar event to Hail
df_merge.loc[df_merge.EVENT_TYPE == 'HAIL FLOODING'] = "Hail"
df_merge.loc[df_merge.EVENT_TYPE == 'HAIL/ICY ROADS'] = "Hail"
df_merge.loc[df_merge.EVENT_TYPE == 'Marine Hail'] = "Hail"

# Testing Event_Type join, similar event to Volcanic Ash
df_merge.loc[df_merge.EVENT_TYPE == 'Volcanic Ashfall'] = "Volcanic Ash"

# Testing Event_Type join, similar event to Dense Fog
df_merge.loc[df_merge.EVENT_TYPE == 'Marine Dense Fog'] = "Dense Fog"

# %%
Event_Type_Data_GB = df_merge.groupby(["EVENT_TYPE"])
test = Event_Type_Data_GB["STATE"].count()
test.keys()
# Out:
# Index(['Body of Waters', 'Dense Fog', 'Dense Smoke', 'Dust Storm', 'Floods',
#        'Hail', 'Heat', 'Hurricanes', 'Landslide', 'Northern Lights', 'OTHER',
#        'Snow', 'Thunderstorms', 'Tornadoes', 'Tsunami', 'Volcanic Ash',
#        'Wildfire', 'Winds'],
#       dtype='object', name='EVENT_TYPE')
